# %%
# %matplotlib notebook

import pandas as pd
import matplotlib.pyplot as plt
from itertools import count
import random
from matplotlib.animation import FuncAnimation

x_vals = []
y_vals = []

y1=[1,4,5,2,1,7]

index = count()

def animate(i):
    
    x_vals.append(next(index))
    y_vals.append(y1[i]) 

    
    plt.cla()
    plt.plot(x_vals, y_vals)
    
ani = FuncAnimation(plt.gcf() , animate , interval=1000 )   
    
plt.plot(x_vals, y_vals)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation, writers
import numpy as np
  
fig = plt.figure(figsize = (7,5))
axes = fig.add_subplot(1,1,1)
axes.set_ylim(0, 10)
palette = ['yellow', 'black', 'green', 
           'red', 'maroon', 'blue']
  
y1, y2, y3, y4, y5, y6 = [], [], [], [], [], []

y11, y21, y31, y41, y51, y61 = [1,2,3,5,7], [1.1,2,3.4,6,8], [2,3,6,8,9], [1,2,5,8,9], [1,2,3,7,6], [1,2,3,4,1]

def animation_function(i):
    y1 = y11[i]
    y2 = y21[i]
    y3 = y31[i]
    y4 = y41[i]
    y5 = y51[i]
    y6 = y61[i]
    
    plt.cla()    
    plt.xlabel("testowe kategorie - zmiana w czasie")
    plt.ylabel("testowe dane")
      
    plt.bar(["Dana1", "Dana2", "Dana3", 
             "Dana4", "Dana5", "Dana6"],
            [y1, y2, y3, y4, y5, y6],
            color = palette)

plt.title("Bar Chart Animation")
  
animation = FuncAnimation(fig, animation_function, 
                          interval = 1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# %matplotlib notebook

from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import numpy as np
  
x1 =[[5, 7, 8], [5, 7, 8, 9], [5, 7, 8, 9, 2, 9, 4], [11, 12, 9], [6, 9, 8], [87, 88, 100], [86, 10, 87], [94, 78, 77]]
 
y1 =[[5, 7, 8], [5, 7, 8, 9], [5, 7, 8, 9, 2, 9, 4], [11, 12, 9], [6, 9, 8], [87, 88, 100], [86, 10, 87], [94, 78, 77]]

x=[]
y=[]
    
def animation_func(i):
    
    plt.cla()
    x=x1[i]
    y=y1[i]
    
    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.scatter(x, y, c = "blue")
    
    plt.xlabel("testowe kategorie - ruch kropek w czasie")
    plt.ylabel("testowe dane")
    
    ax.text(0.9, 0.1, i, transform=ax.transAxes, 
            color='#777777', size=26, ha='right',
            weight=800)

fig, ax = plt.subplots(figsize=(8, 5))    
animation = FuncAnimation(fig, animation_func, 
                          interval = 500)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook

from wordcloud import WordCloud, STOPWORDS

import matplotlib.pyplot as plt

text="Woda, Powietrze, Ziemia, Ogień, Trawa, Niebo, Lód, Drzewo, Niebo"
stopwords = set(STOPWORDS)
cloud = WordCloud(background_color="white", max_words=200, mask=None, 
        stopwords=stopwords, min_font_size=6, width=800, height=400)
 
wordcloud = cloud.generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

x =[5, 7, 8, 7, 2, 17, 2, 9,
    4, 11, 12, 9, 6]
 
y =[99, 86, 87, 88, 100, 86,
    103, 87, 94, 78, 77, 85, 86]
 
plt.scatter(x, y, c ="green")
plt.xlabel("testowe kategorie")
plt.ylabel("testowe dane") 
# To show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import random
import matplotlib
from matplotlib import animation
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook


l1 = [random.randint(-5,2)+(i**1.83)/(random.randint(13,14)) for i in range(0,80,2)]
l2 = [random.randint(-10,-5)+(i**1.6)/(random.randint(10,12)) for i in range(0,80,2)]
l3 = [random.randint(-20,-10)-(i**1.3)/(random.randint(11,12)) for i in range(0,80,2)]
root_list = [random.randint(-80,-75)+(i**1.5)/(random.randint(10,11)) for i in range(0,80,2)]

l1 = root_list + l1
l2 = root_list + l2
l3 = root_list + l3

plt.style.use("seaborn")

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (10,5))
axes.set_ylim(-300, 500)
axes.set_xlim(1980, 2060)
plt.xlabel("testowe kategorie")
plt.ylabel("testowe dane") 

x1,y1,y2,y3 = [], [], [], []
def animate(i):
    
    x1.append(1980+i)
    y1.append((l1[i]))
    y2.append((l2[i]))
    y3.append((l3[i]))
    
    axes.plot(x1,y1, color="red", linewidth=0.5)    
    axes.plot(x1,y3, color="blue", linewidth=0.5)
    axes.plot(x1,y2, color="gray", linewidth=1)
    
anim = FuncAnimation(fig, animate, interval=50)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn")
plt.figure(figsize=(9.2,5))

coal = [8447, 8881, 8886, 9324, 9408, 9124, 9147, 9401, 9716, 9453]
gas = [4761, 4817, 5084, 4978, 5128, 5467, 5695, 5787, 5959, 6186]
hydro = [3422, 3491, 3656, 3797, 3888, 3889, 4032, 4075, 4190, 4246]
nuclear = [2725, 2612, 2434, 2454, 2502, 2536, 2572, 2591, 2657, 2756]
oil = [946, 1060, 1130, 1087, 1045, 1058, 1004, 927, 921, 861]
solar = [32, 63, 98, 136, 197, 256, 328, 445, 578, 711]
wind = [346, 440, 530, 639, 713, 829, 961, 1137, 1265, 1417]

year = [i+2012 for i in range(10)]

colors = sns.color_palette("RdBu", 7)
labels=["dana1", "dana2", "dana3", "dana4", "dana5", "dana6", "dana7"]
plt.stackplot(year, coal, gas, oil, nuclear, hydro, wind, solar, labels=labels, colors=colors)
         
plt.legend(loc = "upper center", bbox_to_anchor=(1.07, 0.8), ncol=1)
plt.title('Testowe dane na wykresie warstwowym')
plt.ylabel('opis osi y')
plt.xticks(np.arange(2012,2022,step=1), rotation=40)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="920">
