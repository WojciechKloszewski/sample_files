# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %%
#european data portal

# %%
plane = pd.read_csv('dane/Air_Traffic_Passenger_Statistics.csv')
#jeśli jest tabulator
#plane = pd.read_csv('dane/Air_Traffic_Passenger_Statistics.csv', delimeter='\t')

# %%
plane
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507        Air Canada                          AC
# 4               200507        Air Canada                          AC
# ...                ...               ...                         ...
# 18393           201803  Volaris Airlines                          Y4
# 18394           201803  Volaris Airlines                          Y4
# 18395           201803           WOW Air                          WW
# 18396           201803           WOW Air                          WW
# 18397           201803           WOW Air                          WW
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
#jeśli zachodzi rozdzielenie danych przecinkami: - split
# x=routes['nazwa_kolumny'].str.split(',' , expand=True)
#następnie zmień nazwy kolumn
# routes_desc.rename({0:'unit', 1:'tra_mass',2:'airport'},axis=1,inplace=True)
#złącz
#routes = routes_desc.join(routes)
#usuń zbędną kolumnę
#routes.desc.drop('tu nazwa kolumny do usunięcia' , axis=1, inplace=True)

# %%
url = 'http://www.floatrates.com/daily/chf.json'

# %%
pd.read_json(url).transpose()
# Out:
#     code alphaCode numericCode                         name         rate  \
# usd  USD       USD         840                  U.S. Dollar     1.045023
# eur  EUR       EUR         978                         Euro     0.971671
# gbp  GBP       GBP         826          U.K. Pound Sterling     0.827232
# cad  CAD       CAD         124              Canadian Dollar     1.327942
# jpy  JPY       JPY         392                 Japanese Yen   132.902689
# ..   ...       ...         ...                          ...          ...
# hrk  HRK       HRK         191                Croatian Kuna     7.334114
# dzd  DZD       DZD         012               Algerian Dinar   151.494143
# ars  ARS       ARS         032               Argentine Peso   124.152149
# stn  STN       STN         930  São Tomé and Príncipe Dobra    23.995558
# bif  BIF       BIF         108              Burundian franc  2127.843086
#
#                               date inverseRate
# ...

# %%
#eksport danych

# %%
df_blood = pd.DataFrame({'Group' : ['0','0','A','AB'],
                        'Rh' : ['+','+','-','-'],
                        'Population' : ['200','43','80','976']
                        })

# %%
df_blood
# Out:
#   Group Rh Population
# 0     0  +        200
# 1     0  +         43
# 2     A  -         80
# 3    AB  -        976

# %%
df_blood.to_csv('blood.csv', index=False)

# %%
pd.read_csv('blood.csv')
# Out:
#   Group Rh  Population
# 0     0  +         200
# 1     0  +          43
# 2     A  -          80
# 3    AB  -         976

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group','Rh'], sep=';')

# %%
#jeśli rozdzielone inaczej niż standardowo przecinek to trzeba podać separator danych
pd.read_csv('blood.csv', sep=';')
# Out:
#   Group Rh
# 0     0  +
# 1     0  +
# 2     A  -
# 3    AB  -

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group','Rh'], sep=';',
               mode='a', header=False)
#mode - append - dodaj do poprzedniego pliku a nie zastąp

# %%
pd.read_csv('blood.csv', sep=';')
# Out:
#   Group Rh
# 0     0  +
# 1     0  +
# 2     A  -
# 3    AB  -
# 4     0  +
# 5     0  +
# 6     A  -
# 7    AB  -

# %%
df_blood.to_json('blood.json')

# %%
pd.read_json('blood.json')
# Out:
#   Group Rh  Population
# 0     0  +         200
# 1     0  +          43
# 2     A  -          80
# 3    AB  -         976

# %%
#praca z excel
#musisz instalować xlrd oraz openpyxl

# %%
# sheet_name - jaki chcemy importować arkusz
auto = pd.read_excel('dane/PC_vehicles-in-use.xlsx', sheet_name=[1,2,3])

# %%
#chcemy arkusz 1
auto[1]
# Out:
#    REGIONS/COUNTRIES       2005       2006       2007       2008       2009  \
# 0            AUSTRIA   4157.000   4205.000   4246.000   4285.000   4360.000
# 1            BELGIUM   4861.000   4929.000   5006.000   5087.000   5160.000
# 2            DENMARK   1971.000   2026.000   2075.000   2105.000   2126.000
# 3            FINLAND   2414.477   2489.287   2480.880   2449.722   2449.604
# 4             FRANCE  30100.000  30400.000  30700.000  30850.000  31050.000
# 5            GERMANY  46090.000  46570.000  41184.000  41321.000  41738.000
# 6             GREECE   4303.129   4543.016   4798.530   5023.944   5131.960
# 7            ICELAND    187.000    197.000    208.000    210.000    205.000
# 8            IRELAND   1662.157   1778.861   1882.901   1924.281   1902.429
# 9              ITALY  34667.000  35297.000  35680.000  36105.000  36372.000
# 10        LUXEMBOURG    307.000    315.000    322.000    329.000    332.000
# ...

# %%
#zapisz dane do excel

# %%
excelWriter = pd.ExcelWriter('cars.xlsx')

# %%
auto[1].to_excel(excelWriter, index=False, columns=['REGIONS/COUNTRIES',2010], sheet_name='Old Europe 2010')

# %%
auto[1].to_excel(excelWriter, index=False, columns=['REGIONS/COUNTRIES',2011], sheet_name='Old Europe 2011')

# %%
excelWriter.save()
#zapisuje dane
