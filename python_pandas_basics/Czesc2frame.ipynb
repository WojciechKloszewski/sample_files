# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %%
obj = pd.read_csv("dane/Mcdonalds.csv")
obj.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#wybrać niektóe kolumny, dodatkowo kolumna Item to index
frame = pd.read_csv("dane/Mcdonalds.csv")
obj = pd.read_csv("dane/Mcdonalds.csv", usecols=['Item','Calories'], index_col='Item')
obj.head()
# Out:
#                                   Calories
# Item
# Egg McMuffin                           300
# Egg White Delight                      250
# Sausage McMuffin                       370
# Sausage McMuffin with Egg              450
# Sausage McMuffin with Egg Whites       400

# %%
frame.count()
#ile jest obiektów dla danej kategorii
# Out:
# Category                         260
# Item                             260
# Serving Size                     260
# Calories                         260
# Calories from Fat                260
# TotalFat                         260
# Total Fat (% Daily Value)        260
# Saturated Fat                    260
# Saturated Fat (% Daily Value)    260
# Trans Fat                        260
# Cholesterol                      260
# Cholesterol (% Daily Value)      260
# Sodium                           260
# Sodium (% Daily Value)           260
# Carbohydrates                    260
# Carbohydrates (% Daily Value)    260
# Dietary Fiber                    260
# Dietary Fiber (% Daily Value)    260
# Sugars                           260
# Protein                          260
# Vitamin A (% Daily Value)        260
# Vitamin C (% Daily Value)        260
# Calcium (% Daily Value)          260
# Iron (% Daily Value)             260
# dtype: int64

# %%
len(frame)
# Out:
# 260

# %%
#typ danych
frame.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# TotalFat                         float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
frame.shape
#atrybyt określające ile wymiarów mają dane - tu 260 wierszy 24 kolumny
# Out:
# (260, 24)

# %%
frame.axes
# oś współrzędnych+wykaz kolumn
# Out:
# [RangeIndex(start=0, stop=260, step=1),
#  Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#         'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#         'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#         'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#         'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#         'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#         'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#         'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#        dtype='object')]

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=260, step=1)

# %%
frame.columns
#opisuje nazwy kolumn
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
frame.values 
#składa się z obiektów lista list
# Out:
# array([['Breakfast', 'Egg McMuffin', '4.8 oz (136 g)', ..., 0, 25, 15],
#        ['Breakfast', 'Egg White Delight', '4.8 oz (135 g)', ..., 0, 25,
#         8],
#        ['Breakfast', 'Sausage McMuffin', '3.9 oz (111 g)', ..., 0, 25,
#         10],
#        ...,
#        ['Smoothies & Shakes', 'McFlurry with Oreo Cookies (Snack)',
#         '6.7 oz (190 g)', ..., 0, 25, 6],
#        ['Smoothies & Shakes',
#         "McFlurry with Reese's Peanut Butter Cups (Medium)",
#         '14.2 oz (403 g)', ..., 0, 60, 6],
#        ['Smoothies & Shakes',
#         "McFlurry with Reese's Peanut Butter Cups (Snack)",
#         '7.1 oz (202 g)', ..., 0, 30, 4]], dtype=object)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   TotalFat                       260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#na rzecz danej kolumny można wywołać value counts - ile jest danego typu danych
frame['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
#przykład losowy ,gdy dodamy n=3 to 3 próbki , frac=0,02 - pokaż 2% danych
frame.sample(n=3)
# Out:
#           Category                             Item    Serving Size  Calories  \
# 27       Breakfast  Big Breakfast (Regular Biscuit)  9.5 oz (269 g)       740
# 3        Breakfast        Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 67  Chicken & Fish          Bacon Cheddar McChicken    6 oz (171 g)       480
#
#     Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 27                430      48.0                         73           17.0
# 3                 250      28.0                         43           10.0
# 67                220      24.0                         38            7.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 27                             87        0.0  ...             51
# 3                              52        0.0  ...             30
# 67                             35        0.0  ...             43
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# ...

# %%
type(frame)
# Out:
# pandas.core.frame.DataFrame

# %%
#pokaż z tabeli dane kaloryczne 
frame.Calories.head()
# Out:
# 0    300
# 1    250
# 2    370
# 3    450
# 4    400
# Name: Calories, dtype: int64

# %%
frame.Calories.mean()
# .median()  .max()
# Out:
# 368.2692307692308

# %%
#na której pozycji martość max
frame.Calories.idxmax()
# Out:
# 82

# %%
frame.Item[82]
# frame.Item[frame.Calories.idxmax()]
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
#inny sposób
frame['Item'][82]
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
#podzbiór dataframe
frame = frame[['Item','Category','Calories','TotalFat','Sugars','Protein','Cholesterol']].head()

# %%
frame
#dodawanie i usuwanie kolumn
# Out:
#                                Item   Category  Calories  TotalFat  Sugars  \
# 0                      Egg McMuffin  Breakfast       300      13.0       3
# 1                 Egg White Delight  Breakfast       250       8.0       3
# 2                  Sausage McMuffin  Breakfast       370      23.0       2
# 3         Sausage McMuffin with Egg  Breakfast       450      28.0       2
# 4  Sausage McMuffin with Egg Whites  Breakfast       400      23.0       2
#
#    Protein  Cholesterol
# 0       17          260
# 1       18           25
# 2       14           45
# 3       21          285
# 4       21           50

# %%
#dodaj nową kolumnę 
frame['Nowa'] = 0

# %%
frame.head()
# Out:
#                                Item   Category  Calories  TotalFat  Sugars  \
# 0                      Egg McMuffin  Breakfast       300      13.0       3
# 1                 Egg White Delight  Breakfast       250       8.0       3
# 2                  Sausage McMuffin  Breakfast       370      23.0       2
# 3         Sausage McMuffin with Egg  Breakfast       450      28.0       2
# 4  Sausage McMuffin with Egg Whites  Breakfast       400      23.0       2
#
#    Protein  Cholesterol  Nowa
# 0       17          260     0
# 1       18           25     0
# 2       14           45     0
# 3       21          285     0
# 4       21           50     0

# %%
zlacz = frame.Sugars+frame.Protein
frame['Nowa'] = zlacz
frame.head()
# Out:
#                                Item   Category  Calories  TotalFat  Sugars  \
# 0                      Egg McMuffin  Breakfast       300      13.0       3
# 1                 Egg White Delight  Breakfast       250       8.0       3
# 2                  Sausage McMuffin  Breakfast       370      23.0       2
# 3         Sausage McMuffin with Egg  Breakfast       450      28.0       2
# 4  Sausage McMuffin with Egg Whites  Breakfast       400      23.0       2
#
#    Protein  Cholesterol  Nowa
# 0       17          260    20
# 1       18           25    21
# 2       14           45    16
# 3       21          285    23
# 4       21           50    23

# %%
#inny rodzaj na wstawienie kolumny na danej pozycji
frame.insert(loc=2, column="SPF", value=frame.Sugars+frame.Protein)
frame.head()
# Out:
#                                Item   Category  SPF  Calories  TotalFat  \
# 0                      Egg McMuffin  Breakfast   20       300      13.0
# 1                 Egg White Delight  Breakfast   21       250       8.0
# 2                  Sausage McMuffin  Breakfast   16       370      23.0
# 3         Sausage McMuffin with Egg  Breakfast   23       450      28.0
# 4  Sausage McMuffin with Egg Whites  Breakfast   23       400      23.0
#
#    Sugars  Protein  Cholesterol  Nowa
# 0       3       17          260    20
# 1       3       18           25    21
# 2       2       14           45    16
# 3       2       21          285    23
# 4       2       21           50    23

# %%
del frame['Nowa']
frame.head()
# Out:
#                                Item   Category  SPF  Calories  TotalFat  \
# 0                      Egg McMuffin  Breakfast   20       300      13.0
# 1                 Egg White Delight  Breakfast   21       250       8.0
# 2                  Sausage McMuffin  Breakfast   16       370      23.0
# 3         Sausage McMuffin with Egg  Breakfast   23       450      28.0
# 4  Sausage McMuffin with Egg Whites  Breakfast   23       400      23.0
#
#    Sugars  Protein  Cholesterol
# 0       3       17          260
# 1       3       18           25
# 2       2       14           45
# 3       2       21          285
# 4       2       21           50

# %%
# inna metoda
frame = frame.drop(columns=['SPF'])
frame.head()
# Out:
#                                Item   Category  Calories  TotalFat  Sugars  \
# 0                      Egg McMuffin  Breakfast       300      13.0       3
# 1                 Egg White Delight  Breakfast       250       8.0       3
# 2                  Sausage McMuffin  Breakfast       370      23.0       2
# 3         Sausage McMuffin with Egg  Breakfast       450      28.0       2
# 4  Sausage McMuffin with Egg Whites  Breakfast       400      23.0       2
#
#    Protein  Cholesterol
# 0       17          260
# 1       18           25
# 2       14           45
# 3       21          285
# 4       21           50

# %%
# inna metoda na usuwanie z kolumn i wierszy axix=1 -kolumny, 0 - wiersze
frame.drop(labels='Sugars',axis=1,inplace=True)

# %%
frame.head()
# Out:
#                                Item   Category  Calories  TotalFat  Protein  \
# 0                      Egg McMuffin  Breakfast       300      13.0       17
# 1                 Egg White Delight  Breakfast       250       8.0       18
# 2                  Sausage McMuffin  Breakfast       370      23.0       14
# 3         Sausage McMuffin with Egg  Breakfast       450      28.0       21
# 4  Sausage McMuffin with Egg Whites  Breakfast       400      23.0       21
#
#    Cholesterol
# 0          260
# 1           25
# 2           45
# 3          285
# 4           50

# %%
#dropna

# %%
frame = pd.read_csv("dane/Mcdonalds.csv")
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#wstawianie wartości
frame.loc[1,'Calories']=np.NaN
frame.loc[2,'TotalFat']=np.NaN
frame.loc[4,'Category']=np.NaN
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4        NaN  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       NaN                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.dropna().head()
# Out:
#     Category                                           Item    Serving Size  \
# 0  Breakfast                                   Egg McMuffin  4.8 oz (136 g)
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
#
#    Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 0     300.0                120      13.0                         20
# 3     450.0                250      28.0                         43
# 4     400.0                210      23.0                         35
# 5     430.0                210      23.0                         36
# 6     460.0                230      26.0                         40
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
#usunięcie tylko tych pozycji które są wszystkie puste
frame.dropna(how='all').head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       NaN                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#usunięcie tylko tych pozycji które mają puste wartości w podanych kolumnach
frame.dropna(subset=['TotalFat']).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
# 5  Breakfast              Steak & Egg McMuffin  6.5 oz (185 g)     430.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
# 5                210      23.0                         36            9.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#usuwamy kolumny z zerami axis=1 ; wiersze axis=0 ; inplace=True - zapisz
frame.dropna(axis=1).head()
# Out:
#     Category                              Item    Serving Size  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
#
#    Calories from Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120                         20            5.0
# 1                 70                         12            3.0
# 2                200                         35            8.0
# 3                250                         43           10.0
# 4                210                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 0                             25        0.0          260
# 1                             15        0.0           25
# ...

# %%
#wypełnij puste dane fillna wartością 0
frame.fillna(value=0).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       0.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4          0  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       0.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
dictionary = {'Category':'UNKNOWN','Calories':0 , 'TotalFat':0}
frame.fillna(value=dictionary).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       0.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4    UNKNOWN  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       0.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#inny sposób dla danej kolumny
frame['Category'].fillna(value='UNKNOWN' , inplace=True)

# %%
#wypełnienie wartością średnią
avg=frame['TotalFat'].mean()
frame['TotalFat'].fillna(avg, inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4    UNKNOWN  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70   8.000000                         12            3.0
# 2                200  14.131274                         35            8.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#skopiowanie poprzedniej wartości
frame['Calories'].fillna(method='ffill' , inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     300.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4    UNKNOWN  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70   8.000000                         12            3.0
# 2                200  14.131274                         35            8.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#sortowanie danych ; na_posiotion - gdzie są dane zerowe
frame.sort_values(by=['Category','Calories'], ascending=[False,True], na_position='first').head()
# Out:
#            Category                              Item    Serving Size  \
# 4           UNKNOWN  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 101  Snacks & Sides                      Apple Slices   1.2 oz (34 g)
# 100  Snacks & Sides                        Side Salad   3.1 oz (87 g)
# 99   Snacks & Sides                 Kids French Fries   1.3 oz (38 g)
# 102  Snacks & Sides           Fruit 'n Yogurt Parfait  5.2 oz (149 g)
#
#      Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 4       400.0                210      23.0                         35
# 101      15.0                  0       0.0                          0
# 100      20.0                  0       0.0                          0
# 99      110.0                 50       5.0                          8
# 102     150.0                 20       2.0                          3
#
#      Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
frame.loc[1,'Serving Size'] = np.NaN

# %%
#by mieć dokładne info o zajmowanej przez plik pamięci
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   259 non-null    object
#  3   Calories                       260 non-null    float64
#  4   Calories from Fat              260 non-null    int64
#  5   TotalFat                       260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#konwersja danych, rzutowanie nie jest możliwe dla NaN
frame['Calories'].fillna(value=0, inplace=True)

# %%
#zmiana typu - oszczędzanie pamięci
frame['Calories'] = frame['Calories'].astype('int')

# %%
frame['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             41
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# UNKNOWN                1
# Name: Category, dtype: int64

# %%
#spadek użycia pamięci przy powtarzających się wartościach
frame['Category'] = frame['Category'].astype('category')

# %%
#ranking kaloryczności dań ; 0.5 bo ktoś jest egzekwo
frame['rank'] = frame['Calories'].rank(ascending=False)
frame.sort_values(by='Calories', ascending=False).head(10)
# Out:
#                Category                                               Item  \
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 32            Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31            Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34            Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33            Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 81       Chicken & Fish                       Chicken McNuggets (20 piece)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
#
#         Serving Size  Calories  Calories from Fat  TotalFat  \
# 82   22.8 oz (646 g)      1880               1060     118.0
# ...

# %%
#największe 3 wartości rankingu kalorii
# nsmallest - najmniejsze
frame.nlargest(n=3, columns='Calories')
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  Calories from Fat  TotalFat  \
# 82  22.8 oz (646 g)      1880               1060     118.0
# 32  15.3 oz (434 g)      1150                540      60.0
# 31  14.8 oz (420 g)      1090                510      56.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                        182           20.0                            101
# 32                         93           20.0                            100
# 31                         87           19.0                             96
#
#     Trans Fat  ...  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82        1.0  ...                             39              6
# ...

# %%
#filtrowanie danych

# %%
#znajdź śniadania o liczbie kalorii >=400
x = frame['Calories'] >= 400
calories = frame[x]

# %%
isBreakfast = frame['Category'] == 'Breakfast'

# %%
frame[isBreakfast & x].head()
# Out:
#     Category                                               Item  \
# 3  Breakfast                          Sausage McMuffin with Egg
# 5  Breakfast                               Steak & Egg McMuffin
# 6  Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7  Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
#
#      Serving Size  Calories  Calories from Fat  TotalFat  \
# 3  5.7 oz (161 g)       450                250      28.0
# 5  6.5 oz (185 g)       430                210      23.0
# 6  5.3 oz (150 g)       460                230      26.0
# 7  5.8 oz (164 g)       520                270      30.0
# 8  5.4 oz (153 g)       410                180      20.0
#
#    Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 3                         43           10.0                             52
# 5                         36            9.0                             46
# ...

# %%
#coś czymś nie jest
frame[~isBreakfast].head()
# Out:
#        Category                                       Item    Serving Size  \
# 4       UNKNOWN           Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 42  Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 43  Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 44  Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 45  Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
#
#     Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 4        400                210      23.0                         35
# 42       530                240      27.0                         42
# 43       520                240      26.0                         41
# 44       600                260      29.0                         45
# 45       610                280      31.0                         48
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
color = ['green','green','blue','blue','red','red','white']
size=['s','s','s','m','m','m','L']
gender = ['m','w','m','w','m','w','u']
clothes = pd.DataFrame({'color':color , 'size':size , 'gender':gender})
clothes
# Out:
#    color size gender
# 0  green    s      m
# 1  green    s      w
# 2   blue    s      m
# 3   blue    m      w
# 4    red    m      m
# 5    red    m      w
# 6  white    L      u

# %%
isColorBlue = clothes['color'] == 'blue'
isColorGreen = clothes['color'] == 'green'
isColorBRed = clothes['color'] == 'red'
isGenderM = clothes['gender'] == 'm'
isGenderW = clothes['gender'] == 'w'
isSizeS = clothes['size'] == 's'
isSizeM = clothes['size'] == 'm'

# %%
clothes[isColorBlue & isGenderM & isSizeS]
# Out:
#   color size gender
# 2  blue    s      m

# %%
#lub
clothes[isColorBlue | isGenderM | isSizeS]
# Out:
#    color size gender
# 0  green    s      m
# 1  green    s      w
# 2   blue    s      m
# 3   blue    m      w
# 4    red    m      m

# %%
#lub oraz i
clothes[(isColorBlue | isGenderM) & isSizeS]
# Out:
#    color size gender
# 0  green    s      m
# 2   blue    s      m

# %%
has400calories = frame['Calories'] >=400
frame.where(has400calories).dropna(how='all').head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4    UNKNOWN               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 3     450.0              250.0      28.0                       43.0
# 4     400.0              210.0      23.0                       35.0
# 5     430.0              210.0      23.0                       36.0
# 6     460.0              230.0      26.0                       40.0
# 7     520.0              270.0      30.0                       47.0
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
#sql
frame.query('Category == "Desserts"').head()
# Out:
#      Category                   Item     Serving Size  Calories  \
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 103                110      13.0                         19            7.0
# 104                 70       8.0                         12            3.5
# 105                 50       6.0                          9            2.5
# 106                 10       1.5                          2            1.0
# 107                 80       9.0                         14            7.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 103                             35        0.0  ...
# ...

# %%
frame.query('Category in ["Desserts","Beverages"] ').head()
# Out:
#      Category                   Item     Serving Size  Calories  \
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 103                110      13.0                         19            7.0
# 104                 70       8.0                         12            3.5
# 105                 50       6.0                          9            2.5
# 106                 10       1.5                          2            1.0
# 107                 80       9.0                         14            7.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 103                             35        0.0  ...
# ...

# %%
frame.query('Category == "Desserts" and Calories <200 ').head()
# Out:
#      Category                   Item     Serving Size  Calories  \
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 104                 70       8.0                         12            3.5
# 105                 50       6.0                          9            2.5
# 106                 10       1.5                          2            1.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 104                             19        0.0  ...
# 105                             13        0.0  ...
# 106                              4        0.0  ...
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 104                              7              1
# 105                              7              1
# ...

# %%
#jakie wartości są w "in" w zbiorze
kolor = clothes['color'].isin(['blue','green'])
clothes[kolor]
# Out:
#    color size gender
# 0  green    s      m
# 1  green    s      w
# 2   blue    s      m
# 3   blue    m      w

# %%
clothes.loc[3,'gender'] = np.NaN

# %%
# znajdź wartości nienullowe
clothes['gender'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# Name: gender, dtype: bool

# %%
# znajdź wartości nullowe
clothes['gender'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# Name: gender, dtype: bool

# %%
x = frame['Calories'].between(300,400)
frame[x].head()
# Out:
#      Category                                            Item    Serving Size  \
# 0   Breakfast                                    Egg McMuffin  4.8 oz (136 g)
# 1   Breakfast                               Egg White Delight             NaN
# 2   Breakfast                                Sausage McMuffin  3.9 oz (111 g)
# 4     UNKNOWN                Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 20  Breakfast  Bacon, Egg & Cheese McGriddles with Egg Whites  6.3 oz (178 g)
#
#     Calories  Calories from Fat   TotalFat  Total Fat (% Daily Value)  \
# 0        300                120  13.000000                         20
# 1        300                 70   8.000000                         12
# 2        370                200  14.131274                         35
# 4        400                210  23.000000                         35
# 20       400                140  15.000000                         24
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
#czy wartości są unikalne dla tabeli kolor
clothes['color'].is_unique
# Out:
# False

# %%
#zwrócić listę kolorów unikalnych
clothes['color'].unique()
# Out:
# array(['green', 'blue', 'red', 'white'], dtype=object)

# %%
#ile jest kolorów unikalnych , funkcja opuszcza wartości nullowe
# jeśli nie chcemy opuścić wartości nullowych : len(clothes['color'].unique())
clothes['color'].nunique()
# Out:
# 4

# %%
#czy wartość zduplikowana ; last - ostatni jako niepowtarzający się
clothes['color'].duplicated(keep='first')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: color, dtype: bool

# %%
#pokarz tabelę bez zduplikowanych kolorów
x = clothes['color'].duplicated(keep='first')
clothes[x]
# Out:
#    color size gender
# 1  green    s      w
# 3   blue    m    NaN
# 5    red    m      w

# %%
clothes.drop_duplicates(['color','size'])
# Out:
#    color size gender
# 0  green    s      m
# 2   blue    s      m
# 3   blue    m    NaN
# 4    red    m      m
# 6  white    L      u
