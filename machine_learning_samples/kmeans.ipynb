# %%
# samples from w3schools

from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import numpy as np

Data = {'x': [25,34,22,27,33,33,31,22,35,34,67,54,57,43,50,57,59,52,65,47,49,48,35,33,44,45,38,43,51,46],
        'y': [79,51,53,78,59,74,73,57,69,75,51,32,40,47,53,36,35,58,59,50,25,20,14,12,20,5,29,27,8,7]
       }
#create plot with points
df = DataFrame(Data,columns=['x','y'])
df.plot(kind="scatter", x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#Run the code in Python, and you’ll see 4 clusters:
kmeans = KMeans(n_clusters=4).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['x'], df['y'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[43.2        16.7       ]
#  [30.83333333 74.66666667]
#  [55.1        46.1       ]
#  [27.75       55.        ]]

# %%
X,y = make_blobs(n_samples = 500,centers = 5,cluster_std = 0.6)
plt.scatter(X[:,0],X[:,1])

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
y_pred = kmeans.predict(X)
plt.scatter(X[:,0],X[:,1],c=y_pred,cmap='viridis')

# %%
#create chart with 1000 random numbers from a normal data distribution
#The first array will have the mean set to 5.0 with a standard deviation of 1.0.
#The second array will have the mean set to 10.0 with a standard deviation of 2.0

x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()
